# %%
class Dictionary:

    def __init__(self, size):
        self.size = size
        self.slots = [None] * self.size
        self.data = [None] * self.size

    def put(self, key, value):
        hash_value = self.hash_function(key)

        # First position
        if self.slots[hash_value] is None:
            self.slots[hash_value] = key
            self.data[hash_value] = value
            return

        # Same key -> update
        if self.slots[hash_value] == key:
            self.data[hash_value] = value
            return

        # Quadratic probing
        i = 1

        while i < self.size:
            new_hash_value = (hash_value + i * i) % self.size

            if self.slots[new_hash_value] is None:
                self.slots[new_hash_value] = key
                self.data[new_hash_value] = value
                return

            if self.slots[new_hash_value] == key:
                self.data[new_hash_value] = value
                return

            i += 1

        raise Exception("Hash table is full")

    def __setitem__(self, key, value):
        self.put(key, value)

    def get(self, key):
        start_position = self.hash_function(key)

        i = 0

        while i < self.size:
            current = (start_position + i * i) % self.size

            if self.slots[current] is None:
                return "Not Found"

            if self.slots[current] == key:
                return self.data[current]

            i += 1

        return "Not Found"

    def __getitem__(self, key):
        return self.get(key)

    def __str__(self):
        for i in range(len(self.slots)):
            if self.slots[i] is not None:
                print(self.slots[i], ":", self.data[i], end=", ")

        return ""

    def hash_function(self, key):
        return abs(hash(key)) % self.size

# %%
D1 = Dictionary(3)

# %%
print(D1)

# %%
D1.put("apple", 1)
D1.put("banana", 2)

# %%
print(D1)
# Out:
# apple : 4, banana : 2, carry : 3,

# %%
D1.put("ok", 4)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31848\924197267.py in <module>
# ----> 1 D1.put("ok", 4)
#
# ~\AppData\Local\Temp\ipykernel_31848\571527535.py in put(self, key, value)
#      37             i += 1
#      38
# ---> 39         raise Exception("Hash table is full")
#      40
#      41     def __setitem__(self, key, value):
#
# Exception: Hash table is full
