# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)

# %%
c

# %%
int(0x1bd0558e0a0)
# Out:
# 1911350157472

# %%
1911350159200
1911350159680
1911350157472
# Out:
# 1911350159200

# %%
print(c.data)
# Out:
# 3

# %%
a.next = b
b.next = c

# %%
print(a.next)

# %%
int(0x000001BD0558E940)
# Out:
# 1911350159680

# %%
print(b.next)

# %%
int(0x000001BD0558E0A0)
# Out:
# 1911350157472

# %%
print(c.next)
# Out:
# None

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

# %%
class LinkedList:
    
    def __init__(self):
        self.head = None
        self.n = 0
        
    def __len__(self):
        return self.n #Number of nodes in LinkedList
    
    def insert_head(self,value):
        new_node = Node(value) #create new node
        
        new_node.next = self.head #making connection between nodes by assinging address of each other
        
        self.head = new_node #assigning new node as head
        
#         self.n = self.n + 1
        self.n += 1 # increment n by 1
    
    def append(self,value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.n += 1
            return
        
        curr = self.head
        while curr.next!= None:
            curr = curr.next
            
        curr.next = new_node
        self.n += 1
    
    def __str__(self):
        curr = self.head
        if curr == None:
            return "Empty Linked List"
        result = ''
        while curr != None:
            result = result + str(curr.data) + '->'
            curr = curr.next
            
        return result[:-2]

# %%
L = LinkedList()

# %%
len(L)
# Out:
# 0

# %%
L.insert_head(1)
L.insert_head(2)
L.insert_head(3)
L.insert_head(4)

# %%
L.traverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20176\1332867973.py in <module>
# ----> 1 L.traverse()
#
# AttributeError: 'LinkedList' object has no attribute 'traverse'

# %%
print(L)
# Out:
# 4->3->2->1

# %%
int(0x000001BD0559E9A0)
# Out:
# 1911350225312

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

# %%
class LinkedList2:
    def __init__(self):
        self.head = None
        self.n = 0
        
    def insert_head(self,value):
        curr = self.head
        new_node = Node(value)
        new_node.next = curr
        self.head = new_node
        self.n += 1
        
    def insert_after(self,after,value):
        new_node = Node(value)
        curr = self.head
        
        while curr != None:
            if curr.data == after:
                break
                
            curr = curr.next
            
        if curr != None:
            new_node.next = curr.next
            curr.next = new_node
            self.n += 1
        else:
            return "Item Not Found"
    
    def append(self,value):
        new_node = Node(value)
        
        if self.head == None:
            self.head = new_node
            self.n += 1
            return
        
        curr = self.head
        while curr.next != None:
            curr = curr.next
            
        curr.next = new_node
        self.n += 1
        
    def clear(self):
        self.head = None
        self.n = 0
    
    def delete_head(self):
        if self.head == None:   # For Empty Linked List
            return "Empty Linked List" 
        self.head = self.head.next
        self.n -= 1
        
    def pop(self):
        curr = self.head
        if curr == None:
            return "Empty Linked List"
        if curr.next == None:
            return self.delete_head()
        
        while curr.next.next != None:
            curr = curr.next
            
        curr.next = None
        self.n -= 1
        
    def remove(self,value):
        
        if self.head == None:
            return "Empty Linked List"
        
        if self.head.data == value:
            return self.delete_head()
        
        curr = self.head
        
        while curr.next != None:
            if curr.next.data == value:
                break
            curr = curr.next
        if curr.next == None:
            return "Item Not Found"
        else:
            curr.next = curr.next.next
            self.n -= 1
            
    def __delitem__(self,index):
        curr = self.head
        pos = 0
        
        if index == 0:
            return self.delete_head()
        
        while curr.next != None:
            if pos == index -1:
                break
            curr = curr.next
            pos += 1
        if curr.next == None:
            return "Item Not Found"
        else:
            curr.next = curr.next.next
            self.n -= 1
    
    def search(self,value):
        curr = self.head
        pos = 0
        
        while curr != None:
            if curr.data == value:
                return pos
            curr = curr.next
            pos += 1
        return "Item not found"
    
    def __getitem__(self, index):
        curr = self.head
        pos = 0
        
        while curr != None:
            if pos == index:
                return curr.data
            curr = curr.next
            pos += 1
        return "IndexError"
    
    
    def __len__(self):
        return self.n
    
    def traverse(self):
        curr = self.head
        
        while curr != None:
            print(curr.data)
            curr = curr.next
            
    def __str__(self):
        curr = self.head
        if curr == None:
            return "Empty Linked List"
        result = ''
        while curr != None:
            result = result + str(curr.data) + '->'
            curr = curr.next
            
        return result[:-2]
    
    def replace_max(self,value):
        curr = self.head
        maxi = curr
        
        while curr != None:
            if curr.data > maxi.data:
                maxi = curr
            curr = curr.next
        maxi.data = value
        
    def sum_odds(self):
        temp = self.head
        counter = 0
        result = 0
        
        while temp != None:
            if counter %2 != 0:
                result = result + temp.data
            counter +=1
            temp = temp.next
        print(result)
        
    def reverse(self):
        prev_node = None
        curr_node = self.head
        
        while curr_node != None:
            next_node = curr_node.next
            curr_node.next  = prev_node
            prev_node = curr_node
            curr_node = next_node
        self.head = prev_node
        
    def change_sent(self):
        temp = self.head
        
        while temp != None:
            if temp.data == '*' or temp.data == '/':
                temp.data = " "
                if temp.next.data == '*' or temp.next.data == '/':
                    temp.next.next.data = temp.next.next.data.upper()
                    temp.next = temp.next.next
            temp = temp.next

# %%
Li = LinkedList2()

# %%
Li.search(5)
# Out:
# 'Item not found'

# %%
Li[2]
# Out:
# 5

# %%
len(Li)
# Out:
# 0

# %%
Li.append(4)
Li.append(5)

# %%
Li.insert_head(3)

# %%
Li.traverse()
# Out:
# 3
# 3
# 4
# 5
# 4
# 5

# %%
print(Li)
# Out:
# 3->4->5

# %%
Li.head.data
# Out:
# 3

# %%
a = Li.reverse()

# %%
Li.sum_odds()
# Out:
# 13

# %%
Li.replace_max(0)

# %%
del Li[300]

# %%
Li.remove(5)
# Out:
# 'Empty Linked List'

# %%
Li.pop()
# Out:
# 'Empty Linked List'

# %%
Li.delete_head()

# %%
Li.clear()

# %%
Li.insert_after(5,23)

# %%
a = [1,2,3,4]

# %%
# a.insert(self,index,value)
a.insert(2,5)

# %%
a
# Out:
# [1, 2, 5, 3, 4]

# %%
def fun(head):
    if head == None:
        return
    if head.next.next != None:
        print(head.data,"", end='')
        fun(head.next)
    print(head.data,"", end = '')

# %%
a = LinkedList2()

# %%
a.append(1)
a.append(2)
a.append(3)
a.append(4)
a.append(5)

# %%
print(a)
# Out:
# 1->2->3->4->5

# %%
fun(a.head)
# Out:
# 1 2 3 4 3 2 1

# %%
word_list = LinkedList2()

# %%
word_list.append("T")
word_list.append("h")
word_list.append("e")
word_list.append("*")
word_list.append("/")
word_list.append("w")
word_list.append("o")
word_list.append("r")
word_list.append("l")
word_list.append("d")
word_list.append("*")
word_list.append("i")
word_list.append("s")
word_list.append("/")
word_list.append("/")
word_list.append("o")
word_list.append("v")
word_list.append("a")
word_list.append("l")

# %%
print(word_list)
# Out:
# T->h->e-> ->W->o->r->l->d-> ->i->s-> ->O->v->a->l

# %%
word_list.traverse()
# Out:
# T
# h
# e
#
# W
# o
# r
# l
# d
#
# i
# s
#
# O
# v
# a
# l

# %%
word_list.change_sent()
